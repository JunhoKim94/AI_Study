# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./Data/Salaries.csv")
# Out:
# C:\Users\junho\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#데이터 프레임 값 반올림
df.round(2)
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %%
#데이터 필터링
df.query("Id >2 and Id < 10")
# Out:
#    Id       EmployeeName                                      JobTitle  \
# 2   3     ALBERT PARDINI               CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG          WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER  DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6     DAVID SULLIVAN                     ASSISTANT DEPUTY CHIEF II
# 6   7          ALSON LEE            BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8      DAVID KUSHNER                DEPUTY DIRECTOR OF INVESTMENTS
# 8   9     MICHAEL MORRIS            BATTALION CHIEF, (FIRE DEPARTMENT)
#
#   BasePay OvertimePay OtherPay Benefits   TotalPay  TotalPayBenefits  Year  \
# 2  212739      106088  16452.6      NaN  335279.91         335279.91  2011
# 3   77916     56120.7   198307      NaN  332343.61         332343.61  2011
# 4  134402        9737   182235      NaN  326373.19         326373.19  2011
# 5  118602        8601   189083      NaN  316285.74         316285.74  2011
# ...

# %%
df.iloc[:, df.columns != "Id"]
# Out:
#                   EmployeeName  \
# 0               NATHANIEL FORD
# 1                 GARY JIMENEZ
# 2               ALBERT PARDINI
# 3            CHRISTOPHER CHONG
# 4              PATRICK GARDNER
# 5               DAVID SULLIVAN
# 6                    ALSON LEE
# 7                DAVID KUSHNER
# 8               MICHAEL MORRIS
# 9           JOANNE HAYES-WHITE
# 10               ARTHUR KENNEY
# 11            PATRICIA JACKSON
# 12           EDWARD HARRINGTON
# 13                 JOHN MARTIN
# 14              DAVID FRANKLIN
# 15             RICHARD CORRIEA
# 16                    AMY HART
# 17              SEBASTIAN WONG
# 18                  MARTY ROSS
# 19               ELLEN MOFFATT
# 20                  VENUS AZAR
# 21                JUDY MELINEK
# 22               GEORGE GARCIA
# 23               VICTOR WYRSCH
# 24             JOSEPH DRISCOLL
# 25                GREGORY SUHR
# 26                 JOHN HANLEY
# 27              RAYMOND GUZMAN
# 28              DENISE SCHMITT
# ...

# %%
#iloc --> 숫자로 0열 1행 ..
x = df.iloc[1]
#loc --> 실제 인덱스 사용
y = df.loc[1]

# %%
df.describe()
# Out:
#                   Id       TotalPay  TotalPayBenefits           Year  Notes
# count  148654.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    74327.500000   74768.321972      93692.554811    2012.522643    NaN
# std     42912.857795   50517.005274      62793.533483       1.117538    NaN
# min         1.000000    -618.130000       -618.130000    2011.000000    NaN
# 25%     37164.250000   36168.995000      44065.650000    2012.000000    NaN
# 50%     74327.500000   71426.610000      92404.090000    2013.000000    NaN
# 75%    111490.750000  105839.135000     132876.450000    2014.000000    NaN
# max    148654.000000  567595.430000     567595.430000    2014.000000    NaN

# %%
# NaN값을 0으로 채우기

df.fillna(0)
df.replace(np.NaN, 'NULL Value', inplace=True)
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %%
df = df.groupby("EmployeeName")

# %%
df = pd.read_csv("./Data/train_guild.csv")

# %%
df.guild_id
set(df.guild_id)
# Out:
# {'3814e76b7c382e6d7ab97c31709674c2be18bb90b69e14d0669887f156a4f1ae',
#  'e3aed49e52d201244088f560b4cbec959a1300740b141e38db024ed7e535a7f8',
#  'e4101fd0250d03f1fa3226ddd66d20212d53955cc5dea8a17306e5508cf00fc6',
#  '7a47001a88c250b93e4395d5700881c689fb8468b6c5e98b2a1932c64f208791',
#  '2ecd294d1e5dd6cb84be73e880d54715091cef687f95f82720f8ffb8c3d35e93',
#  '6766bf423983772417a460aa6b23ce8038a27a1a18a71dcbbba652d22134e6d2',
#  'a33b8afcc8ee55123bd8286e3e99cd51fd51d31c590f4b9a619a39bc6eb1548c',
#  'b0a1c0a6ef5dc89107bc86c5f604e75869b1c3879894e0f4a29a87dcd97519ba',
#  '4dd8a5121ea2e369104c618d0fc38320c74528f7d53ad9bdeeaef13e1742b41c',
#  '9703668b09f5d085faefb956c649a1d506853f71a322e9fa60dc01005f645a53',
#  '0c97e332df2efff0f82cdf1240d40194b93bb53450e7eff84887bd1d24b83f1f',
#  '5ba92b5a7cfd3c891315e1c03044a243fbd301e0b74ba460468991d8cc002a81',
#  'f1af8a51fa4daac290fdc0fe4d34fec5262ff4f03a00c0618b176c5c501c5eb0',
#  'cbdc19ec38c13f5b89d48452d7ecdd3523856d695b205f16e181757b18803aa3',
# ...

# %%
df = pd.read_csv("./Data/pandasex1.csv")
stack = []

for index in set(df.color):
    x = df.loc[df.color == index]
    stack.append([index,tuple(x.number),len(x.number)])
        
dd = pd.DataFrame(stack)
dd.to_csv("./test.csv")

# %%
df = pd.read_csv("./Data/train_guild.csv")

# %%
df = pd.read_csv("./Data/Salaries.csv")
# Out:
# C:\Users\junho\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df[df.BasePay != 'Not Provided']
#df = df[df.Year == 2011]
df.BasePay = df.BasePay.astype(float)
#NAN값은 따로 처리? --> float로 하면 알아서 처리

# %%
#2011년 job title 별로 basepay 평균

# %%
needs = ['JobTitle','BasePay','OvertimePay','OtherPay','TotalPay','TotalPayBenefits','Year']
df.groupby(needs).mean()
x = df.groupby(['JobTitle','Year'])['BasePay'].mean()
#groupby.mean의 데이터는 series 데이터 --> dataframe 아님

# %%
df.BasePay = df.BasePay.astype(float)
#nan 은 원래 float 구조!
#평균낼때 nan은 제외하고 구해줌!
df[df.Year == 2011]
# Out:
#           Id           EmployeeName  \
# 0          1         NATHANIEL FORD
# 1          2           GARY JIMENEZ
# 2          3         ALBERT PARDINI
# 3          4      CHRISTOPHER CHONG
# 4          5        PATRICK GARDNER
# 5          6         DAVID SULLIVAN
# 6          7              ALSON LEE
# 7          8          DAVID KUSHNER
# 8          9         MICHAEL MORRIS
# 9         10     JOANNE HAYES-WHITE
# 10        11          ARTHUR KENNEY
# 11        12       PATRICIA JACKSON
# 12        13      EDWARD HARRINGTON
# 13        14            JOHN MARTIN
# 14        15         DAVID FRANKLIN
# 15        16        RICHARD CORRIEA
# 16        17               AMY HART
# 17        18         SEBASTIAN WONG
# 18        19             MARTY ROSS
# 19        20          ELLEN MOFFATT
# 20        21             VENUS AZAR
# 21        22           JUDY MELINEK
# 22        23          GEORGE GARCIA
# 23        24          VICTOR WYRSCH
# 24        25        JOSEPH DRISCOLL
# ...

# %%
pd.DataFrame(x)
# Out:
#                                                                BasePay
# JobTitle                                           Year
# ACCOUNT CLERK                                      2011   43300.806506
# ACCOUNTANT                                         2011   46643.172000
# ACCOUNTANT INTERN                                  2011   28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                        2014   62290.780000
# ACUPUNCTURIST                                      2011   66374.400000
# ADMINISTRATIVE ANALYST                             2011   63435.628602
# ADMINISTRATIVE ANALYST II                          2011   59373.710000
# ADMINISTRATIVE ANALYST III                         2011   92698.515000
# ADMINISTRATIVE ENGINEER                            2011  120913.161000
# ADMINISTRATIVE SERVICES MANAGER                    2011   75555.033333
# ADMINISTRATOR, SFGH MEDICAL CENTER                 2011  245124.440000
# ...
